# %%
import pandas as pd
import numpy as np

# %%
df17 = pd.read_excel('../data/stop_frisk/sqf-2017.xlsx', na_values='(null)')

# %%
df17.head()
# Out:
#    STOP_FRISK_ID STOP_FRISK_DATE STOP_FRISK_TIME  YEAR2    MONTH2       DAY2  \
# 0              1      2017-01-16        14:26:00   2017   January     Monday
# 1              2      2017-01-16        14:26:00   2017   January     Monday
# 2              3      2017-02-08        11:10:00   2017  February  Wednesday
# 3              4      2017-02-20        11:35:00   2017  February     Monday
# 4              5      2017-02-21        13:20:00   2017  February    Tuesday
#
#         STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0  Based on Self Initiated                APP                  SGT
# 1  Based on Self Initiated                APP                  SGT
# 2    Based on C/W on Scene                APP                  POM
# 3  Based on Self Initiated                APP                  POM
# 4       Based on Radio Run                APP                  POM
#
#    ISSUING_OFFICER_COMMAND_CODE  ... STOP_LOCATION_SECTOR_CODE  \
# 0                           574  ...                       NaN
# 1                           574  ...                       NaN
# 2                           863  ...                         C
# 3                             1  ...                         H
# 4                             1  ...                         H
#
#    STOP_LOCATION_APARTMENT STOP_LOCATION_FULL_ADDRESS  \
# 0                      NaN       180 GREENWICH STREET
# 1                      NaN       180 GREENWICH STREET
# 2                      NaN    WALL STREET && BROADWAY
# 3                      NaN           75 GREENE STREET
# 4                        2          429 WEST BROADWAY
#
#   STOP_LOCATION_PREMISES_NAME STOP_LOCATION_STREET_NAME STOP_LOCATION_X  \
# 0                         NaN          GREENWICH STREET          982381
# 1                         NaN          GREENWICH STREET          982381
# 2                         NaN               WALL STREET          981005
# 3                         NaN             GREENE STREET          984031
# 4                         NaN             WEST BROADWAY          983894
#
#    STOP_LOCATION_Y STOP_LOCATION_ZIP_CODE  STOP_LOCATION_PATROL_BORO_NAME  \
# 0           201750                    NaN                            PBMS
# 1           201750                    NaN                            PBMS
# 2           197131                    NaN                            PBMS
# 3           202796                    NaN                            PBMS
# 4           203523                    NaN                            PBMS
#
#   STOP_LOCATION_BORO_NAME
# 0               MANHATTAN
# 1               MANHATTAN
# 2               MANHATTAN
# 3               MANHATTAN
# 4               MANHATTAN
#
# [5 rows x 83 columns]

# %%
df17.to_csv('../data/stop_frisk/2017.csv',index=False)

# %%
df17.STOP_LOCATION_X.dtype
# Out:
# dtype('O')

# %%
df18 = pd.read_excel('../data/stop_frisk/sqf-2018.xlsx', na_values='(null)')

# %%
df18.head()
# Out:
#    STOP_FRISK_ID STOP_FRISK_DATE Stop Frisk Time  YEAR2   MONTH2    DAY2  \
# 0              1      2018-01-01        19:04:00   2018  January  Monday
# 1              2      2018-01-01        23:00:00   2018  January  Monday
# 2              3      2018-01-01        23:55:00   2018  January  Monday
# 3              4      2018-01-01        03:23:00   2018  January  Monday
# 4              5      2018-01-01        03:23:00   2018  January  Monday
#
#       STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0  Based on C/W on Scene                APP                  POM
# 1     Based on Radio Run                APP                  POM
# 2     Based on Radio Run                APP                  POM
# 3     Based on Radio Run                APP                  POM
# 4     Based on Radio Run                APP                  POM
#
#    ISSUING_OFFICER_COMMAND_CODE  ... STOP_LOCATION_SECTOR_CODE  \
# 0                             1  ...                         G
# 1                            34  ...                         C
# 2                           808  ...                         B
# 3                            63  ...                         B
# 4                            63  ...                         B
#
#    STOP_LOCATION_APARTMENT        STOP_LOCATION_FULL_ADDRESS  \
# 0                      NaN  VARICK STREET && FRANKLIN STREET
# 1                      NaN     DYCKMAN STREET && POST AVENUE
# 2                       4M               2245 RANDALL AVENUE
# 3                      NaN        EAST 38 STREET && AVENUE L
# 4                      NaN        EAST 38 STREET && AVENUE L
#
#   STOP_LOCATION_PREMISES_NAME STOP_LOCATION_STREET_NAME STOP_LOCATION_X  \
# 0                         NaN             VARICK STREET          982327
# 1                         NaN            DYCKMAN STREET         1004892
# 2                         NaN            RANDALL AVENUE         1026706
# 3                         NaN            EAST 38 STREET         1001347
# 4                         NaN            EAST 38 STREET         1001347
#
#    STOP_LOCATION_Y STOP_LOCATION_ZIP_CODE  STOP_LOCATION_PATROL_BORO_NAME  \
# 0           201274                    NaN                            PBMS
# 1           253548                    NaN                            PBMN
# 2           237776                    NaN                            PBBX
# 3           166195                    NaN                            PBBS
# 4           166195                    NaN                            PBBS
#
#   STOP_LOCATION_BORO_NAME
# 0               MANHATTAN
# 1               MANHATTAN
# 2                   BRONX
# 3                BROOKLYN
# 4                BROOKLYN
#
# [5 rows x 83 columns]

# %%
df18.WEAPON_FOUND_FLAG.value_counts()
# Out:
# N    10054
# Y      954
# Name: WEAPON_FOUND_FLAG, dtype: int64

# %%
df18.to_csv('../data/stop_frisk/2018.csv',index=False)

# %%
df2011 = pd.read_csv('../data/stop_frisk/2011_top.csv', encoding='cp437', )

# %%
df2011.head()
# Out:
#    year  pct  ser_num  datestop  timestop recstat inout trhsloc  perobs  \
# 0  2011  102      185   1012011         0       A     O       P       1
# 1  2011  115       50   1012011         5       A     O       P       1
# 2  2011  100        4   1012011         7       1     O       H       1
# 3  2011  100        3   1012011         7       1     O       H       1
# 4  2011  100        1   1012011         7       1     O       H       1
#
#    crimsusp  ...  zip addrpct sector          beat post   xcoord  \
# 0  BURGLARY  ...          102      B                     1030708
# 1       FEL  ...          115      I                     1021302
# 2       CPW  ...          100      B             4   34  1037668
# 3       CPW  ...          100      B             4   34  1037668
# 4       CPW  ...          100      B             4   34  1037668
#
#          ycoord dettypcm  linecm  detailcm
# 0        194185       CM       1        14
# 1        213563       CM       1        85
# 2        153549       CM       1        20
# 3        153549       CM       1        20
# 4        153549       CM       1        20
#
# [5 rows x 112 columns]

# %%
df2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Columns: 112 entries, year to detailcm
# dtypes: int64(19), object(93)
# memory usage: 874.2+ KB

# %%
filespecs = {year : pd.read_excel(f'../data/stop_frisk/filespecs/{year} SQF File Spec.xlsx', header=3) for year in range(2003, 2018)}
filespecs[2003]
# Out:
#      Variable  Position                             Label Measurement Level  \
# 0        year         1               YEAR OF STOP (CCYY)           Nominal
# 1         pct         2  PRECINCT OF STOP (FROM 1 TO 123)           Nominal
# 2     ser_num         3               UF250 SERIAL NUMBER           Nominal
# 3    datestop         4         DATE OF STOP (MM-DD-YYYY)           Nominal
# 4    timestop         5              TIME OF STOP (HH:MM)             Scale
# ..        ...       ...                               ...               ...
# 106    xcoord       107          LOCATION OF STOP X COORD           Nominal
# 107    ycoord       108          LOCATION OF STOP Y COORD           Nominal
# 108  dettypCM       109                DETAILS TYPES CODE           Nominal
# 109    lineCM       110       COUNT >1 ADDITIONAL DETAILS           Nominal
# 110  detailCM       111            CRIME CODE DESCRIPTION           Nominal
#
#      Column Width Alignment Print Format Write Format
# 0               5      Left           A5           A5
# 1               4      Left           A4           A4
# 2               7      Left           A7           A7
# 3               8     Right           F8           F8
# 4               8      Left           A5           A5
# ..            ...       ...          ...          ...
# 106            24      Left          A32          A32
# 107            24      Left           A6           A6
# 108            24      Left           A2           A2
# 109            24      Left           A5           A5
# 110             6      Left          A78          A78
#
# [111 rows x 8 columns]

# %%
filespecs2018 = pd.read_excel(f'../data/stop_frisk/filespecs/2018 SQF File Spec.xlsx')
filespecs2018
# Out:
#    Stop, Question, and Frisk. Stop, Question and Frisk Trespass  \
# 0                                       STOP_FRISK_ID
# 1                                     STOP_FRISK_DATE
# 2                                     Stop Frisk Time
# 3                                               YEAR2
# 4                                              MONTH2
# ..                                                ...
# 78                                    STOP_LOCATION_X
# 79                                    STOP_LOCATION_Y
# 80                             STOP_LOCATION_ZIP_CODE
# 81                     STOP_LOCATION_PATROL_BORO_NAME
# 82                            STOP_LOCATION_BORO_NAME
#
#    Variable Position
# 0                  A
# 1                  B
# 2                  C
# 3                  D
# 4                  E
# ..               ...
# 78                CA
# 79                CB
# 80                CC
# 81                CD
# 82                CE
#
# [83 rows x 2 columns]

# %%
for year in range(2004,2017):
    print(year, filespecs[2003].equals(filespecs[year]))
# Out:
# 2004 True
# 2005 True
# 2006 True
# 2007 True
# 2008 True
# 2009 True
# 2010 True
# 2011 False
# 2012 False
# 2013 False
# 2014 False
# 2015 False
# 2016 False

# %%
for year in range(2012,2017):
    print(year, filespecs[2011].equals(filespecs[year]))
# Out:
# 2012      Variable  Position  Label  Measurement Level  Column Width  Alignment  \
# 0        True      True   True               True          True       True
# 1        True      True   True               True          True       True
# 2        True      True   True               True          True       True
# 3        True      True   True               True          True       True
# 4        True      True   True               True          True       True
# ..        ...       ...    ...                ...           ...        ...
# 107      True      True   True               True          True       True
# 108      True      True   True               True          True       True
# 109      True      True   True               True          True       True
# 110      True      True   True               True          True       True
# 111      True      True   True               True          True       True
#
#      Print Format  Write Format
# 0            True          True
# 1            True          True
# 2            True          True
# 3            True          True
# 4            True          True
# ..            ...           ...
# 107          True          True
# 108          True          True
# 109          True          True
# 110          True          True
# 111          True          True
#
# [112 rows x 8 columns]
# 2013      Variable  Position  Label  Measurement Level  Column Width  Alignment  \
# 0        True      True   True               True          True       True
# 1        True      True   True               True          True       True
# 2        True      True   True               True          True       True
# 3        True      True   True               True          True       True
# 4        True      True   True               True          True       True
# ..        ...       ...    ...                ...           ...        ...
# 107      True      True   True               True          True       True
# 108      True      True   True               True          True       True
# 109      True      True   True               True          True       True
# 110      True      True   True               True          True       True
# 111      True      True   True               True          True       True
#
#      Print Format  Write Format
# 0            True          True
# 1            True          True
# 2            True          True
# 3            True          True
# 4            True          True
# ..            ...           ...
# 107          True          True
# 108          True          True
# 109          True          True
# 110          True          True
# 111          True          True
#
# [112 rows x 8 columns]
# 2014      Variable  Position  Label  Measurement Level  Column Width  Alignment  \
# 0        True      True   True               True          True       True
# 1        True      True   True               True          True       True
# 2        True      True   True               True          True       True
# 3        True      True   True               True          True       True
# 4        True      True   True               True          True       True
# ..        ...       ...    ...                ...           ...        ...
# 107      True      True   True               True          True       True
# 108      True      True   True               True          True       True
# 109      True      True   True               True          True       True
# 110      True      True   True               True          True       True
# 111      True      True   True               True          True       True
#
#      Print Format  Write Format
# 0            True          True
# 1            True          True
# 2            True          True
# 3            True          True
# 4            True          True
# ..            ...           ...
# 107          True          True
# 108          True          True
# 109          True          True
# 110          True          True
# 111          True          True
#
# [112 rows x 8 columns]
# 2015      Variable  Position  Label  Measurement Level  Column Width  Alignment  \
# 0        True      True   True               True          True       True
# 1        True      True   True               True          True       True
# 2        True      True   True               True          True       True
# 3        True      True   True               True          True       True
# 4        True      True   True               True          True       True
# ..        ...       ...    ...                ...           ...        ...
# 107      True      True   True               True          True       True
# 108      True      True   True               True          True       True
# 109      True      True   True               True          True       True
# 110      True      True   True               True          True       True
# 111      True      True   True               True          True       True
#
#      Print Format  Write Format
# 0            True          True
# 1            True          True
# 2            True          True
# 3            True          True
# 4            True          True
# ..            ...           ...
# 107          True          True
# 108          True          True
# 109          True          True
# 110          True          True
# 111          True          True
#
# [112 rows x 8 columns]
# 2016      Variable  Position  Label  Measurement Level  Column Width  Alignment  \
# 0        True      True   True               True          True       True
# 1        True      True   True               True          True       True
# 2        True      True   True               True          True       True
# 3        True      True   True               True          True       True
# 4        True      True   True               True          True       True
# ..        ...       ...    ...                ...           ...        ...
# 107      True      True   True               True          True       True
# 108      True      True   True               True          True       True
# 109      True      True   True               True          True       True
# 110      True      True   True               True          True       True
# 111      True      True   True               True          True       True
#
#      Print Format  Write Format
# 0            True          True
# 1            True          True
# 2            True          True
# 3            True          True
# 4            True          True
# ..            ...           ...
# 107          True          True
# 108          True          True
# 109          True          True
# 110          True          True
# 111          True          True
#
# [112 rows x 8 columns]

# %%
filespecs[2011][~(filespecs[2011] == filespecs[2013]).all(axis=1)]
# Out:
#    Variable  Position                          Label Measurement Level  \
# 91  addrtyp        92  LOCATION OF STOP ADDRESS TYPE           Nominal
#
#     Column Width Alignment Print Format Write Format
# 91             9      Left           A1           A1

# %%
filespecs[2013].loc[91]
# Out:
# Variable                                   addrtyp
# Position                                        92
# Label                PERSON STOP HOME ADDRESS TYPE
# Measurement Level                          Nominal
# Column Width                                     9
# Alignment                                     Left
# Print Format                                    A1
# Write Format                                    A1
# Name: 91, dtype: object

# %% [markdown]
# difference starts at row 79

# %%
filespecs[2003].Variable[filespecs[2003].Variable.ne(filespecs[2011].Variable)]
# Out:
# 79          sex
# 80         race
# 81          dob
# 82          age
# 83      ht_feet
# 84      ht_inch
# 85       weight
# 86     haircolr
# 87     eyecolor
# 88        build
# 89     othfeatr
# 90      addrtyp
# 91      rescode
# 92     premtype
# 93     premname
# 94      addrnum
# 95       stname
# 96      stinter
# 97      crossst
# 98       aptnum
# 99         city
# 100       state
# 101         zip
# 102     addrpct
# 103      sector
# 104        beat
# 105        post
# 106      xcoord
# 107      ycoord
# 108    dettypCM
# 109      lineCM
# 110    detailCM
# Name: Variable, dtype: object

# %%
filespecs[2011].Variable[79]
# Out:
# 'forceuse'

# %% [markdown]
# the only difference is "forceuse"

# %%
filespecs[2003].Variable.equals(filespecs[2011].Variable[:79].append(filespecs[2011].Variable[80:],ignore_index=True))
# Out:
# True

# %%
filespecs[2011].loc[79]
# Out:
# Variable                      forceuse
# Position                            80
# Label                REASON FORCE USED
# Measurement Level              Nominal
# Column Width                         4
# Alignment                         Left
# Print Format                        A1
# Write Format                        A1
# Name: 79, dtype: object

# %%
df2011.forceuse
# Out:
# 0
# 1
# 2
# 3
# 4
#       ..
# 994
# 995
# 996
# 997
# 998
# Name: forceuse, Length: 999, dtype: object

# %%
stop_frisks = {year : pd.read_csv(f'../data/stop_frisk/{year}.csv', encoding='cp437', low_memory=False) for year in range(2003, 2009)}

# %% [markdown]
# Mixed type warnings:
# columns 73, 81,82,83,84,85

# %%
filespecs[2003].loc[73]
# Out:
# Variable                                             repcmd
# Position                                                 74
# Label                REPORTING OFFICER'S COMMAND (1 TO 999)
# Measurement Level                                   Nominal
# Column Width                                              6
# Alignment                                              Left
# Print Format                                             A4
# Write Format                                             A4
# Name: 73, dtype: object

# %%
stop_frisks[2008].age.value_counts() < 100
# Out:
# 18     False
# 19     False
# 20     False
# 17     False
# 21     False
#        ...
# 238     True
# 236     True
# 235     True
# 743     True
# 154     True
# Name: age, Length: 286, dtype: bool

# %%
for year in range(2003, 2009):
    print(year, stop_frisks[year].repcmd.value_counts())
# Out:
# 2003         4172
# 077     3911
# 103     3685
# 075     3266
# 803     2837
#         ...
# VICE       1
# SDRG       1
# NBSI       1
# 76         1
# 232        1
# Name: repcmd, Length: 660, dtype: int64
# 2004         104837
# 75       17574
# 103      16559
# 77        6947
# 67        5772
#          ...
# 460          1
# ONGS         1
# IA           1
# QNTP         1
# OSA8         1
# Name: repcmd, Length: 1484, dtype: int64
# 2005 075     21349
# 077     13269
# 103     13074
# 079      8684
# 101      7425
#         ...
# HG I        1
# TBH0        1
# BXSC        1
# D002        1
# 640         1
# Name: repcmd, Length: 3274, dtype: int64
# 2006 075    21428
# 103    17028
# 802    16121
# 079    12607
# 805    10301
#        ...
# 276        1
# 558        1
# 451        1
# 504        1
# 228        1
# Name: repcmd, Length: 348, dtype: int64
# 2007 802    16410
# 075    15558
# 079    12274
# 070     9336
# 120     8692
#        ...
# 859        1
# 571        1
# 357        1
# 567        1
# 454        1
# Name: repcmd, Length: 343, dtype: int64
# 2008 075    21613
# 802    14889
# 120    12415
# 079    11209
# 070    10175
#        ...
# 248        1
# 571        1
# 454        1
# 263        1
# 276        1
# Name: repcmd, Length: 349, dtype: int64
